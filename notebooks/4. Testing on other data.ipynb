# %% [markdown]
# <font size="3"> Now let's try and test the two models on some other datasets to see how they compare.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.utils import resample
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix, cohen_kappa_score, balanced_accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from joblib import dump, load

def padding(name):
    padded_text = "^" + name.str.upper() + "$"
    return padded_text

def print_metrics(y_test,y_pred):
    bas = balanced_accuracy_score(y_test,y_pred)
    cks = cohen_kappa_score(y_test,y_pred)
    print("Balanced accuracy score : ", round(bas,3))
    print("Cohen Kappa score : ", round(cks, 3))


    report = classification_report(y_test, y_pred, output_dict=True)
    df = pd.DataFrame(report).transpose()
    results = df.sort_values("f1-score",ascending=False)
    return results


pubmed_clf = load("MR_model.joblib")
FB_clf = load("mixed_model.joblib")

# %% [markdown]
# # Forebears

# %% [markdown]
# <font size="3"> [forebears.io/](https://forebears.io/) is a website dedicated to tracking the prevalence of names accross the world. It is based on the largest genealogical database in the world, [FamilySearch.org](https://www.familysearch.org/fr/). I scraped the top 1000 names of every country in the world.

# %%
df_fam = pd.read_csv("../data/other_data/forebears_surnames.csv")
df_fam = df_fam[df_fam["region"] != 'ambiguous'].dropna()

X = df_fam["name"]
y = df_fam["region"]

df_fam
# Out:
#             country     name      freq   region alpha-3
# 0       South Korea      Kim  0.200000    Asian     KOR
# 1       South Korea        I  0.142857    Asian     KOR
# 2       South Korea      Pak  0.083333    Asian     KOR
# 3       South Korea    Chong  0.047619    Asian     KOR
# 4       South Korea     Choe  0.047619    Asian     KOR
# ...             ...      ...       ...      ...     ...
# 153270     Dr Congo  Malemba  0.000125  African     COD
# 153271     Dr Congo    Njiba  0.000125  African     COD
# 153272     Dr Congo  Nshimbi  0.000124  African     COD
# 153273     Dr Congo     Futi  0.000124  African     COD
# 153274     Dr Congo  Kulondi  0.000124  African     COD
#
# [108469 rows x 5 columns]

# %% [markdown]
# ## Results for the Facebook model

# %%
y_pred = FB_clf.predict(X)
results = print_metrics(y ,y_pred)
results
# Out:
# Balanced accuracy score :  0.68
# Cohen Kappa score :  0.626
#                       precision    recall  f1-score        support
# CentralSouthEuropean   0.871898  0.697665  0.775111   33443.000000
# Slavic                 0.787782  0.746835  0.766762   14141.000000
# NorthEuropean          0.601465  0.843490  0.702209   14210.000000
# weighted avg           0.717581  0.689533  0.695075  108469.000000
# accuracy               0.689533  0.689533  0.689533       0.689533
# African                0.736177  0.612337  0.668570   19308.000000
# macro avg              0.657063  0.679935  0.660077  108469.000000
# Asian                  0.631639  0.582955  0.606321    8589.000000
# Arabian                0.528624  0.656533  0.585676   12138.000000
# Indian                 0.441855  0.619729  0.515890    6640.000000

# %% [markdown]
# ## Results for the Pubmed model

# %%
y_pred = pubmed_clf.predict(X)
results = print_metrics(y ,y_pred)
results
# Out:
# Balanced accuracy score :  0.675
# Cohen Kappa score :  0.632
#                       precision    recall  f1-score        support
# CentralSouthEuropean   0.874338  0.715905  0.787229   33443.000000
# Slavic                 0.804718  0.747755  0.775192   14141.000000
# weighted avg           0.718598  0.694779  0.699760  108469.000000
# accuracy               0.694779  0.694779  0.694779       0.694779
# NorthEuropean          0.582927  0.850598  0.691773   14210.000000
# African                0.706572  0.667599  0.686533   19308.000000
# macro avg              0.656650  0.674926  0.658693  108469.000000
# Arabian                0.633214  0.581150  0.606066   12138.000000
# Asian                  0.568687  0.565840  0.567260    8589.000000
# Indian                 0.426094  0.595633  0.496797    6640.000000

# %% [markdown]
# ## Detailed predictions

# %% [markdown]
# Both models seem equally good.
# Let's see in detail how the FB model performed. Here's its predictions for each country as well the share of correct predictions, either raw or weighted by the frequency of each name in the population.

# %%
df_fam["pred"] = y_pred
df_fam["result"] = np.where(df_fam["pred"] == df_fam["region"], "correct",'false')

c = df_fam.groupby(["country","result"])["freq"].count()
c = c/c.groupby("country").transform(sum)
c = (c*100).round(1).unstack()["correct"].rename("correct-unweighted")

a = df_fam.groupby(["country","result"])["freq"].sum()
a = a/a.groupby("country").transform(sum)
a = (a*100).round(1).unstack()["correct"].rename('correct-weighted')


b = df_fam.groupby(["country","pred"])["name"].count()
b = b/b.groupby('country').transform(sum)
b = b.multiply(100).round(1).unstack()
data = pd.concat([c,a,b],axis=1).sort_values("correct-unweighted",ascending=False).fillna(0)
data[:45]
# Out:
#               correct-unweighted  correct-weighted  African  Arabian  Asian  \
# country
# Tajikistan                 100.0             100.0      0.0      0.0    0.0
# Uzbekistan                  99.6              99.8      0.0      0.0    0.0
# Kyrgyzstan                  99.3              99.1      0.1      0.1    0.2
# Russia                      97.8              98.5      0.1      0.4    0.3
# Turkmenistan                96.9              97.5      0.6      0.0    0.0
# Kazakhstan                  94.7              92.6      0.3      0.9    1.1
# Bulgaria                    94.5              95.6      0.7      2.3    0.2
# Netherlands                 94.5              95.6      0.7      2.0    1.1
# Belgium                     93.8              94.7      0.9      1.4    0.5
# Azerbaijan                  93.6              98.7      0.0      0.5    0.0
# Algeria                     93.0              92.3      1.5     93.0    0.1
# Germany                     92.5              94.1      2.0      2.3    0.7
# Lesotho                     91.2              89.9     91.2      2.8    1.7
# Cape Verde                  91.0              89.8      2.7      2.0    0.7
# Belarus                     90.8              91.2      1.5      2.4    0.9
# Botswana                    90.4              91.7     90.4      0.0    0.8
# Austria                     90.3              93.6      0.4      1.7    0.4
# Japan                       90.0              92.4      4.9      1.3   90.0
# Tunisia                     89.9              91.3      1.9     89.9    0.5
# Norway                      89.8              94.2      1.7      3.5    1.7
# Zambia                      89.6              89.9     89.6      2.3    4.5
# Denmark                     89.5              96.1      1.5      3.9    0.8
# Sweden                      89.3              95.0      0.8      4.5    1.4
# Poland                      89.2              92.2      2.2      1.6    1.2
# Morocco                     88.9              90.5      1.4     88.9    0.7
# Italy                       88.3              88.4      3.7      3.1    1.4
# Burundi                     87.5              89.7     87.5      0.0    2.1
# Peru                        86.6              92.4      4.7      2.5    1.4
# Zimbabwe                    86.3              91.5     86.3      2.2    4.0
# Dr Congo                    85.6              90.7     85.6      4.2    2.8
# Argentina                   85.4              92.6      3.7      2.6    1.3
# Yemen                       84.5              80.3      1.5     84.5    0.7
# France                      84.4              84.0      1.9      2.4    0.9
# Ireland                     84.3              84.6      3.8      4.3    1.5
# Bolivia                     84.0              92.5      4.4      3.3    1.2
# Thailand                    83.9              86.7      5.9      2.1   83.9
# Chile                       83.3              91.5      4.8      2.7    1.1
# Jordan                      83.3              83.5      2.9     83.3    1.1
# Jamaica                     83.2              88.6      3.8      3.9    2.7
# Gabon                       83.2              84.3     83.2     11.9    3.0
# Mexico                      82.9              93.1      5.3      2.1    2.1
# Malawi                      82.8              90.7     82.8      3.1    3.5
# Greece                      82.8              86.6      3.2      7.0    0.8
# Rwanda                      82.7              86.4     82.7      0.0    0.9
# Iceland                     82.1              84.8      3.0      5.5    1.3
#
#               CentralSouthEuropean  Indian  NorthEuropean  Slavic
# country
# Tajikistan                     0.0     0.0            0.0   100.0
# Uzbekistan                     0.0     0.4            0.0    99.6
# Kyrgyzstan                     0.1     0.1            0.1    99.3
# Russia                         0.2     0.4            0.8    97.8
# Turkmenistan                   1.9     0.0            0.6    96.9
# Kazakhstan                     0.9     0.7            1.4    94.7
# Bulgaria                       0.4     1.6            0.3    94.5
# Netherlands                    1.1     0.2           94.5     0.3
# Belgium                        2.9     0.2           93.8     0.3
# Azerbaijan                     1.9     3.9            0.1    93.6
# Algeria                        1.5     2.8            0.9     0.2
# Germany                        1.2     0.6           92.5     0.7
# Lesotho                        1.7     1.6            0.8     0.2
# Cape Verde                    91.0     0.1            3.3     0.3
# Belarus                        1.1     1.0            2.3    90.8
# Botswana                       0.8     2.4            5.6     0.0
# Austria                        1.1     0.6           90.3     5.4
# Japan                          1.7     0.9            0.7     0.5
# Tunisia                        1.3     4.7            1.3     0.5
# Norway                         1.3     1.7           89.8     0.3
# Zambia                         1.1     1.4            0.3     0.7
# Denmark                        1.2     1.4           89.5     1.7
# Sweden                         0.7     2.4           89.3     0.9
# Poland                         1.3     0.8            3.7    89.2
# Morocco                        0.4     7.9            0.7     0.0
# Italy                         88.3     0.8            1.8     0.9
# Burundi                        4.2     0.0            4.2     2.1
# Peru                          86.6     0.5            3.3     1.0
# Zimbabwe                       1.5     3.0            2.1     0.9
# Dr Congo                       1.7     4.3            0.9     0.5
# Argentina                     85.4     0.4            5.3     1.3
# Yemen                          0.8     9.9            1.8     0.8
# France                         8.4     0.7           84.4     1.3
# Ireland                        2.6     2.5           84.3     1.0
# Bolivia                       84.0     1.4            4.5     1.2
# Thailand                       0.8     3.8            3.0     0.5
# Chile                         83.3     0.7            6.6     0.8
# Jordan                         0.7     9.7            1.7     0.6
# Jamaica                        3.8     1.8           83.2     0.9
# Gabon                          0.0     0.0            1.0     1.0
# Mexico                        82.9     0.6            5.7     1.3
# Malawi                         3.9     1.6            3.9     1.2
# Greece                        82.8     1.5            3.2     1.5
# Rwanda                         8.2     2.7            5.5     0.0
# Iceland                        6.6     1.3           82.1     0.2

# %%
data[45:90]
# Out:
#                        correct-unweighted  correct-weighted  African  Arabian  \
# country
# Brazil                               81.8              92.9      3.6      2.2
# Switzerland                          81.6              84.9      1.8      6.1
# Venezuela                            81.3              89.4      5.2      2.7
# Uruguay                              80.1              91.5      3.1      3.7
# Paraguay                             80.1              90.7      3.9      2.3
# Ecuador                              79.9              88.4      7.1      2.6
# Nicaragua                            79.6              87.9      5.3      2.2
# Dominican Republic                   79.5              89.3      3.9      3.1
# El Salvador                          79.4              90.8      5.5      2.0
# Spain                                79.1              90.5      4.4      3.2
# Colombia                             79.0              88.3      6.8      3.2
# Iran                                 78.6              85.3      2.7     13.7
# Egypt                                76.8              80.9      4.1     76.8
# Bahamas                              76.8              86.4      5.2      5.3
# Cuba                                 76.7              90.1      4.9      3.9
# Lebanon                              76.5              77.6      3.3     76.5
# Portugal                             76.2              84.1      8.0      2.2
# Luxembourg                           75.8              78.8      1.5      2.3
# Hong Kong                            75.5              78.7      6.9      3.7
# Honduras                             75.2              89.9      4.9      2.4
# Georgia                              75.1              76.2      4.4      1.9
# Djibouti                             75.0              78.8     11.2     75.0
# Sri Lanka                            74.1              61.5      4.7      5.7
# Nigeria                              73.7              78.8     73.7      9.5
# Syria                                73.7              81.7      4.3     73.7
# Republic Of The Congo                73.2              76.8     73.2     16.9
# Finland                              71.4              78.4      3.7      2.8
# Ghana                                71.4              78.1     71.4      9.4
# Libya                                71.0              77.3      6.5     71.0
# Uganda                               70.0              68.0     70.0      8.1
# Cyprus                               69.7              73.1      6.2     11.3
# Panama                               69.6              89.2      4.9      2.7
# Singapore                            69.1              83.3      6.1      6.4
# Puerto Rico                          68.2              85.8      3.9      4.4
# Namibia                              68.1              63.0     68.1      5.2
# Costa Rica                           67.3              90.4      5.5      1.9
# Lithuania                            67.0              69.5      2.2      1.4
# Guatemala                            66.8              83.0      5.4      4.5
# Sudan                                66.4              71.6      9.9     66.4
# Cameroon                             65.6              60.9     65.6     18.4
# Malaysia                             65.3              62.3      4.7      8.0
# Philippines                          63.7              76.7      6.1      3.6
# Slovakia                             63.5              61.8      5.4      6.1
# Bangladesh                           63.4              79.0      3.8     18.7
# Mauritania                           63.1              59.8     14.5     63.1
#
#                        Asian  CentralSouthEuropean  Indian  NorthEuropean  \
# country
# Brazil                   2.0                  81.8     0.7            9.2
# Switzerland              1.1                   6.6     1.6           81.6
# Venezuela                2.0                  81.3     1.3            6.4
# Uruguay                  1.6                  80.1     0.9            9.3
# Paraguay                 1.2                  80.1     1.4           10.2
# Ecuador                  2.4                  79.9     1.6            5.3
# Nicaragua                1.6                  79.6     1.2            9.2
# Dominican Republic       2.1                  79.5     0.6            9.1
# El Salvador              2.2                  79.4     1.7            7.6
# Spain                    2.5                  79.1     1.0            8.8
# Colombia                 1.8                  79.0     1.2            6.3
# Iran                     1.2                   1.7    78.6            1.1
# Egypt                    0.5                   0.5    14.5            1.9
# Bahamas                  1.9                   8.3     1.5           76.8
# Cuba                     1.8                  76.7     0.4           10.9
# Lebanon                  1.7                   2.3    11.6            3.5
# Portugal                 1.7                  76.2     1.1            9.7
# Luxembourg               1.8                  14.9     1.1           75.8
# Hong Kong               75.5                   1.6     3.7            4.9
# Honduras                 1.3                  75.2     1.1           14.2
# Georgia                  1.1                  75.1     2.7            0.0
# Djibouti                 5.0                   1.2     5.0            2.5
# Sri Lanka                6.7                   5.7    74.1            2.6
# Nigeria                  2.3                   1.5     6.0            6.0
# Syria                    1.7                   1.8    13.7            3.6
# Republic Of The Congo    2.5                   2.5     1.6            2.4
# Finland                  2.4                  71.4     2.3           15.1
# Ghana                    3.9                   1.5     4.4            7.4
# Libya                    0.0                   1.6    21.0            0.0
# Uganda                   8.4                   6.5     4.7            1.7
# Cyprus                   1.8                  69.7     1.0            9.0
# Panama                   3.1                  69.6     1.1           17.9
# Singapore               69.1                   1.2    11.0            4.3
# Puerto Rico              2.0                  68.2     1.1           19.2
# Namibia                  3.0                   4.7     3.2           14.7
# Costa Rica               3.3                  67.3     1.2           19.6
# Lithuania                0.0                  67.0     1.1           19.7
# Guatemala                6.8                  66.8     2.4            9.2
# Sudan                    3.1                   0.8    17.6            1.5
# Cameroon                 5.0                   2.4     2.9            4.7
# Malaysia                15.5                   1.0    65.3            4.5
# Philippines             17.0                  63.7     3.3            5.0
# Slovakia                 2.4                   5.5     2.3           14.9
# Bangladesh               3.4                   2.7    63.4            5.2
# Mauritania               1.8                   2.2     5.9           10.9
#
#                        Slavic
# country
# Brazil                    0.5
# Switzerland               1.1
# Venezuela                 1.1
# Uruguay                   1.3
# Paraguay                  1.0
# Ecuador                   1.1
# Nicaragua                 0.9
# Dominican Republic        1.7
# El Salvador               1.6
# Spain                     1.0
# Colombia                  1.7
# Iran                      1.0
# Egypt                     1.6
# Bahamas                   1.2
# Cuba                      1.3
# Lebanon                   1.1
# Portugal                  1.1
# Luxembourg                2.7
# Hong Kong                 3.7
# Honduras                  0.9
# Georgia                  14.8
# Djibouti                  0.0
# Sri Lanka                 0.5
# Nigeria                   1.0
# Syria                     1.2
# Republic Of The Congo     1.0
# Finland                   2.3
# Ghana                     2.0
# Libya                     0.0
# Uganda                    0.6
# Cyprus                    1.1
# Panama                    0.8
# Singapore                 1.8
# Puerto Rico               1.2
# Namibia                   1.0
# Costa Rica                1.2
# Lithuania                 8.6
# Guatemala                 4.9
# Sudan                     0.8
# Cameroon                  1.0
# Malaysia                  1.0
# Philippines               1.3
# Slovakia                 63.5
# Bangladesh                2.9
# Mauritania                1.6

# %%
data[90:]
# Out:
#                         correct-unweighted  correct-weighted  African  \
# country
# South Africa                          63.0              70.2     63.0
# Taiwan                                62.8              96.2      8.3
# India                                 62.8              75.5      7.3
# Malta                                 62.6              56.5      7.0
# China                                 60.7              94.0      7.5
# Haiti                                 60.6              72.3      8.5
# Saudi Arabia                          60.5              60.9      3.7
# Iraq                                  59.8              67.1      4.9
# Kenya                                 59.8              59.0     59.8
# Mali                                  58.5              76.5     58.5
# Afghanistan                           56.7              57.6      4.8
# Turkey                                56.2              61.5      4.6
# Indonesia                             54.9              62.0      5.4
# Slovenia                              54.8              57.3      4.9
# Ukraine                               54.2              58.3      2.3
# Togo                                  53.3              50.2     53.3
# Pakistan                              53.0              56.4      5.7
# Moldova                               53.0              55.5     10.3
# Tanzania                              52.9              44.6     52.9
# Nepal                                 52.4              58.6      9.9
# Mozambique                            50.0              52.5     50.0
# Vietnam                               49.8              76.4     13.6
# Croatia                               49.5              49.9      4.6
# Montenegro                            49.4              53.2      6.5
# Romania                               49.0              46.3     12.6
# Burkina Faso                          47.9              65.0     47.9
# Serbia                                46.9              50.5      5.5
# Benin                                 45.9              40.2     45.9
# Oman                                  45.4              39.4      5.2
# Belize                                42.0              50.5      4.6
# Senegal                               41.9              54.2     41.9
# Myanmar                               40.6              64.3     18.8
# United Arab Emirates                  39.9              49.4      5.1
# Cambodia                              38.7              48.3      7.2
# Bosnia And Herzegovina                37.7              35.7      6.2
# Gambia                                37.5              32.9     37.5
# Ethiopia                              37.2              41.7     37.2
# Mauritius                             36.9              39.1      7.7
# South Korea                           36.6              67.9      6.2
# Guinea                                33.7              68.7     33.7
# Somalia                               33.2              55.3     18.0
# Liberia                               32.3              36.5     32.3
# Albania                               28.9              32.8     19.0
# Hungary                               27.5              26.0     10.1
# Niger                                 26.7              34.4     26.7
# Maldives                              23.4              36.4     13.8
# Estonia                               16.5              17.6      8.7
# Angola                                13.5              13.3     13.5
# Latvia                                12.6              16.7      8.7
# Mongolia                               7.2               7.4      5.6
# Armenia                                0.3               0.1      0.2
#
#                         Arabian  Asian  CentralSouthEuropean  Indian  \
# country
# South Africa                1.5    1.4                   2.0     2.5
# Taiwan                      7.1   62.8                   7.1     3.9
# India                      11.2    5.0                   4.1    62.8
# Malta                      10.5    4.1                  62.6     0.6
# China                       8.5   60.7                   2.8     6.9
# Haiti                       6.5    1.3                  19.3     2.0
# Saudi Arabia               60.5    1.6                   0.0    30.0
# Iraq                       59.8    2.3                   2.2    24.8
# Kenya                       9.2    8.0                   5.6     8.8
# Mali                       19.5    5.1                   4.6     2.1
# Afghanistan                25.9    2.9                   3.6    56.7
# Turkey                     11.7    4.2                  56.2     5.6
# Indonesia                   9.0   54.9                   3.3    23.9
# Slovenia                    6.5    2.6                   6.2     6.9
# Ukraine                     1.3    0.5                  30.8     9.0
# Togo                       31.1    4.4                   8.9     0.0
# Pakistan                   29.2    3.8                   2.1    53.0
# Moldova                     6.2    2.6                  53.0     6.2
# Tanzania                   11.9    4.2                   8.5     7.2
# Nepal                      11.5    9.0                   7.2    52.4
# Mozambique                  1.9    1.9                  40.7     1.9
# Vietnam                    10.6   49.8                   3.7     3.2
# Croatia                     7.8    4.3                   9.1     7.0
# Montenegro                  7.3    3.5                  12.7     6.2
# Romania                     7.7    5.8                  49.0     4.6
# Burkina Faso               23.3    6.0                   8.6     4.5
# Serbia                      7.0    4.4                  13.4     6.0
# Benin                      31.2    2.8                   6.9     2.3
# Oman                       45.4    1.6                   3.3    40.5
# Belize                      4.9    6.7                  42.0     2.9
# Senegal                    19.9    4.9                   9.0     6.7
# Myanmar                    15.3   40.6                   0.6     9.4
# United Arab Emirates       39.9    3.7                   2.1    44.5
# Cambodia                   15.7   38.7                   4.4     7.2
# Bosnia And Herzegovina     12.9    5.0                  11.0    10.3
# Gambia                     26.0    2.1                   7.3    12.5
# Ethiopia                   32.6    3.4                   4.9    10.1
# Mauritius                  36.9    9.5                   3.9    16.4
# South Korea                 7.9   36.6                   6.4    12.4
# Guinea                     30.6    6.7                  10.2     4.9
# Somalia                    33.2    6.2                   4.7    24.2
# Liberia                    14.5    8.1                   4.1     9.3
# Albania                    15.9    6.0                  28.9    10.5
# Hungary                    15.9    4.4                  27.5     4.3
# Niger                      54.2    3.1                   4.9     7.0
# Maldives                   23.4    5.5                   1.1    52.5
# Estonia                     5.8    1.0                  16.5    11.7
# Angola                      1.3    3.2                  67.3     0.6
# Latvia                      3.6    2.8                  12.6     2.8
# Mongolia                   17.3    7.2                   3.2    51.4
# Armenia                     0.3    0.3                   0.3     2.7
#
#                         NorthEuropean  Slavic
# country
# South Africa                     29.3     0.3
# Taiwan                            7.6     3.2
# India                             7.1     2.5
# Malta                            13.5     1.8
# China                            12.2     1.4
# Haiti                            60.6     1.8
# Saudi Arabia                      3.2     1.1
# Iraq                              4.2     1.8
# Kenya                             7.2     1.4
# Mali                              9.7     0.5
# Afghanistan                       3.4     2.7
# Turkey                           12.3     5.4
# Indonesia                         2.1     1.4
# Slovenia                         18.1    54.8
# Ukraine                           1.9    54.2
# Togo                              2.2     0.0
# Pakistan                          4.3     1.9
# Moldova                           9.8    11.9
# Tanzania                         13.9     1.4
# Nepal                             7.7     2.3
# Mozambique                        1.9     1.9
# Vietnam                          15.6     3.5
# Croatia                          17.8    49.5
# Montenegro                       14.5    49.4
# Romania                          12.6     7.7
# Burkina Faso                      8.1     1.6
# Serbia                           16.8    46.9
# Benin                            10.3     0.6
# Oman                              2.8     1.2
# Belize                           36.8     2.2
# Senegal                          16.4     1.3
# Myanmar                          12.4     2.9
# United Arab Emirates              3.4     1.2
# Cambodia                         18.4     8.4
# Bosnia And Herzegovina           17.0    37.7
# Gambia                           12.5     2.1
# Ethiopia                          9.5     2.4
# Mauritius                        24.7     1.0
# South Korea                      28.8     1.7
# Guinea                           13.1     0.9
# Somalia                          10.4     3.3
# Liberia                          30.2     1.5
# Albania                           0.7    19.0
# Hungary                          20.7    17.1
# Niger                             3.0     1.1
# Maldives                          2.5     1.2
# Estonia                          42.7    13.6
# Angola                           12.8     1.3
# Latvia                           39.5    30.0
# Mongolia                         12.4     2.8
# Armenia                           0.0    96.2

# %% [markdown]
# # Olympic athletes

# %% [markdown]
# <font size="3"> A [dataset](https://github.com/rgriff23/Olympic_history) of athletes having competed in the Olympics.

# %%
df_sport = pd.read_csv("https://raw.githubusercontent.com/rgriff23/Olympic_history/master/data/athlete_events.csv").drop_duplicates(subset=["Name","Team"])
df_sport["name"] = df_sport["Name"].str.split().apply(lambda x : x[-1]).str.upper()
df_sport["country"] = df_sport["Team"]
df_sport = df_sport.merge(labels,on="country")[["country",'Name',"name","region"]].dropna()
df_sport = df_sport[df_sport["region"] != 'ambiguous']
df_sport
# Out:
#        country                Name           name   region
# 0        China           A Dijiang        DIJIANG    Asian
# 1        China            A Lamusi         LAMUSI    Asian
# 2        China       Abudoureheman  ABUDOUREHEMAN    Asian
# 3        China           Ai Linuer         LINUER    Asian
# 4        China           Ai Yanhan         YANHAN    Asian
# ...        ...                 ...            ...      ...
# 97171  Lesotho       Masempe Theko          THEKO  African
# 97172  Lesotho     Mamorallo Tjoka          TJOKA  African
# 97173  Lesotho  M'apotlaki Ts'elho        TS'ELHO  African
# 97174  Lesotho          Lefa Tsapi          TSAPI  African
# 97175  Lesotho       Mosolesa Tsie           TSIE  African
#
# [92103 rows x 4 columns]

# %% [markdown]
# ## Performance of the FB model

# %%
y = df_sport["region"]
y_pred = FB_clf.predict(df_sport['name'])
results = print_metrics(y ,y_pred)
results
# Out:
# Balanced accuracy score :  0.708
# Cohen Kappa score :  0.657
#                       precision    recall  f1-score       support
# Asian                  0.849078  0.803084  0.825441  10375.000000
# Slavic                 0.786534  0.811755  0.798945  11570.000000
# NorthEuropean          0.756835  0.843610  0.797870  29663.000000
# weighted avg           0.770805  0.734439  0.740615  92103.000000
# accuracy               0.734439  0.734439  0.734439      0.734439
# CentralSouthEuropean   0.882178  0.617045  0.726168  30202.000000
# macro avg              0.635046  0.708042  0.653484  92103.000000
# Arabian                0.380345  0.789811  0.513437   3435.000000
# Indian                 0.407337  0.635978  0.496604   2357.000000
# African                0.383019  0.455010  0.415922   4501.000000

# %% [markdown]
# ## Performance of the PubMed model

# %%
y = df_sport["region"]
y_pred = pubmed_clf.predict(df_sport['name'])
results = print_metrics(y ,y_pred)
results
# Out:
# Balanced accuracy score :  0.716
# Cohen Kappa score :  0.672
#                       precision    recall  f1-score       support
# Asian                  0.817989  0.817831  0.817910  10375.000000
# NorthEuropean          0.751641  0.849071  0.797391  29663.000000
# Slavic                 0.791052  0.797753  0.794389  11570.000000
# weighted avg           0.772443  0.747326  0.751257  92103.000000
# accuracy               0.747326  0.747326  0.747326      0.747326
# CentralSouthEuropean   0.881571  0.645752  0.745456  30202.000000
# macro avg              0.655027  0.716332  0.675607  92103.000000
# Arabian                0.527982  0.733333  0.613941   3435.000000
# Indian                 0.418696  0.634705  0.504553   2357.000000
# African                0.396254  0.535881  0.455610   4501.000000

# %% [markdown]
# <font size="3"> The Pubmed dataset does a bit better.

# %% [markdown]
# # Insee names dataset

# %% [markdown]
# <font size="3">  The french National Institute of Statistics keeps a database of most names given at birth since the 1890's. In 1890-1900 almost all names should be of north european origin with a minority coming from south europe. Let's see how the FB model performs.

# %% [markdown]
# ## FB model

# %%
fr_names = pd.read_table("https://www.insee.fr/fr/statistiques/fichier/3536630/noms2008nat_txt.zip")
fr_names = fr_names[fr_names["NOM"] != "AUTRES"]

fr_names["pred"] = FB_clf.predict(fr_names["NOM"])

data_xix = fr_names.groupby("pred")["_1891_1900"].sum()
data_xxi = fr_names.groupby("pred")["_1991_2000"].sum()

data_xix = ((data_xix/data_xix.sum())*100).sort_values(ascending=False).round(1)
data_xxi = ((data_xix/data_xxi.sum())*100).sort_values(ascending=False).round(1)

data = pd.concat([data_xix.astype(str) + "%",data_xix.cumsum()],axis=1)
data.columns = ["share_1890_1900",'cumulative_share_1890_1900']
data
# Out:
#                      share_1890_1900  cumulative_share_1890_1900
# pred
# NorthEuropean                  87.5%                        87.5
# CentralSouthEuropean            5.5%                        93.0
# Arabian                         2.8%                        95.8
# African                         1.6%                        97.4
# Slavic                          1.1%                        98.5
# Indian                          0.9%                        99.4
# Asian                           0.7%                       100.1

# %% [markdown]
# <font size="3"> Quite good, although at least 7% of names are wrongly labeled as non european. Let's review some random predictions.

# %%
for region in ['CentralSouthEuropean',"African","Arabian",'Indian',"Asian","Slavic"]:
    n = fr_names[(fr_names["pred"] == region) & (fr_names["_1891_1900"] > 20)].sample(50)["NOM"]
    print('Examples of predicted', region, " names : ")
    for i in n:
        print(i.capitalize(), end=", ")
    print('\n')
# Out:
# Examples of predicted CentralSouthEuropean  names :
# Hermez, Barbaste, Carrega, Canel, Pasquini, Rostagni, Cistac, Cristol, Ottomani, Prete, Giuliano, Franceschini, Morio, Occelli, Gaglio, Kerlidou, Ghigo, Marin, Sabate, Mauri, Durando, Esposito, Dorso, Catalan, Sacaze, Zanetti, Ozon, Guiliani, Seveno, Barbas, Corticchiato, Capus, Mondoloni, Pellan, Colomban, Ayral, Roccaserra, Sartori, Chambas, Rosso, Donato, Petrignani, Solari, Benedetti, Marchini, Francoz, Filippini, Garibaldi, Maestracci, Benedetto,
#
# Examples of predicted African  names :
# Emile, Mazy, Mangon, Joye, Lehuede, Dazy, Moity, Nony, Marle, Dodu, Lelu, Menu, Pogu, Danilo, Bondu, Molas, Sibue, Magendie, Dibon, Cabane, Dile, Matheu, Sence, Quidu, Surugue, Mabru, Thabuis, Dube, Lebegue, Lerendu, Mazingue, Basile, Rame, Andree, Nogue, Eme, Bigo, Maxime, Seube, Ramus, Phalip, Adams, Chiesa, Angele, Cande, Emery, Donze, Uteza, Gabon, Comba,
#
# Examples of predicted Arabian  names :
# Baysse, Jaouen, Mine, Lamm, Knab, Eloi, Routaboul, Dijoud, Bes, Rabache, Erramouspe, Bichat, Dassy, Lachal, Nabos, Maissa, Bueb, Bonifassi, Agez, Noury, Aboulin, Boulo, Gouas, Babel, Mehay, Soula, Prioul, Lejour, Bouchu, Marsan, Amy, Chanat, Cheradame, Bastouil, Salat, Souilhat, Germa, Albouy, Boudey, Bedou, Boche, Bass, Puech, Papy, Darbo, Wassmer, Laby, Menou, Gueno, Ham,
#
# Examples of predicted Indian  names :
# Baratin, Merian, Loyal, Julou, Haristoy, Ravat, Dabadie, Pra, Sahut, Nesa, Daridan, Jacob, Arvis, Chavand, Lalu, Arthur, Payan, Noyon, Pournin, Girma, Montaz, Mathurin, Amare, Jayet, Jary, Nizan, Moizan, Adrian, Arnal, Gobin, Golias, Tual, Sury, Gargam, Lotode, Girin, Galinie, Chomat, Balan, Dole, Ramin, Pade, Daste, Nathan, Chandezon, Fare, Divay, Fizaine, Sivade, Nal,
#
# Examples of predicted Asian  names :
# Pratlong, Dutoya, Thaon, Prima, Parsy, Tribut, Kancel, Haon, Chanon, Laot, Chirat, Chol, Dagorn, Tamet, Manon, Chantry, Fereol, Vatin, Bibal, Lerda, Beltzung, Carn, Siau, Prache, Yung, Tamain, Somprou, Buon, Manac h, Rohee, Chatin, Chomarat, Suel, Uny, Guillemoto, Pompanon, Christy, Kueny, Generat, Hengy, Pasty, Laxague, Sube, Pradines, Kerisit, Beon, Padiou, Toque, Priam, Jung,
#
# Examples of predicted Slavic  names :
# Eysseric, Seznec, Mazan, Pernin, Gentric, Pizon, Gorin, Chapin, Romac, Cholat, Arhan, Flohic, Judic, Kermarec, Clodic, Queva, Bricka, Marhic, Cuzin, Salin, Chupin, Malric, Meuric, Lezin, Goavec, Becar, Cazin, Dulin, Domec, Vic, Longin, Posnic, Melchior, Genin, Perny, Mazin, Sapin, Samyn, Surzur, Busin, Cavarec, Nedelec, Domin, Podvin, Palin, Dhenin, Provin, Janin, Bodin, Lirzin,

# %% [markdown]
# <font size="3"> Most Southern european names are right, almost all of the others are wrong. Breton names are classified a lot as slavic because of "ic", "ec" endings.

# %% [markdown]
# ## Pubmodel model

# %%
fr_names["pred"] = pubmed_clf.predict(fr_names["NOM"])

data_xix = fr_names.groupby("pred")["_1891_1900"].sum()
data_xxi = fr_names.groupby("pred")["_1991_2000"].sum()

data_xix = ((data_xix/data_xix.sum())*100).sort_values(ascending=False).round(1)
data_xxi = ((data_xix/data_xxi.sum())*100).sort_values(ascending=False).round(1)

data = pd.concat([data_xix.astype(str) + "%",data_xix.cumsum()],axis=1)
data.columns = ["share_1890_1900",'cumulative_share_1890_1900']
data
# Out:
#                      share_1890_1900  cumulative_share_1890_1900
# pred
# NorthEuropean                  75.7%                        75.7
# CentralSouthEuropean           14.6%                        90.3
# African                         3.4%                        93.7
# Arabian                         2.1%                        95.8
# Slavic                          1.5%                        97.3
# Asian                           1.4%                        98.7
# Indian                          1.2%                        99.9

# %%
for region in ['CentralSouthEuropean',"African","Arabian",'Indian',"Asian","Slavic"]:
    n = fr_names[(fr_names["pred"] == region) & (fr_names["_1891_1900"] > 20)].sample(50)["NOM"]
    print('Examples of predicted', region, " names : ")
    for i in n:
        print(i.capitalize(), end=", ")
    print('\n')
# Out:
# Examples of predicted CentralSouthEuropean  names :
# Cance, Cabal, Cristofari, Raimondi, Gilli, Verdan, Espie, Echegut, Hocde, Cayla, Blanque, Perfettini, Ristori, Larrere, Serra, Capus, Nalis, Peraldi, Ughetto, Mauran, Lofficial, Lea, Humez, Pasquiou, Busso, Escaffre, Daragon, Russo, Borredon, Soyez, Guidicelli, Guinel, Solere, Bossis, Roumeas, Rolando, Bocage, Vives, Gas, Gandolfo, Gipoulou, De vos, Pantalacci, Calvin, Caraes, Riou, Lahondes, Vivares, Car, Lauriol,
#
# Examples of predicted African  names :
# Mao, Sereni, Lembeye, Gouzou, Fousse, Adolphe, Sire, Mone, Demade, Coffy, Onno, Mabile, Blampain, Lesire, Gouyou, Donguy, Lelong, Fol, Duchange, Caritey, Bole, Aguesse, Foata, Brou, Mathou, Laye, Le doare, Peru, Marguerite, Dange, Boussange, Longere, Chaze, Bugat, Roye, Emery, Chenu, Machu, Manne, Duminy, Petitbon, Justin, Seraphin, Justine, Deleplanque, Meresse, Bally, Bodo, Odiot, Isidore,
#
# Examples of predicted Arabian  names :
# Belgy, Retif, Gibout, Sache, Belou, Bas, Derail, Reboud, Nabos, Hannedouche, Daout, Amiet, Allouis, Touja, Bouffil, Bout, Bellamy, Ache, Gamel, Lahache, Moyroud, Hamy, Laclef, Retout, Kerouedan, Boudry, Goiffon, Blache, Albouze, Albo, Mouny, Abbal, Fouache, Bellair, Herrou, Chabanas, Jaboulay, Aboulin, Souty, Vallat, Belair, Cardine, Guine, Louail, Gernigon, Moury, Mari, Dehay, Bougain, Duhil,
#
# Examples of predicted Indian  names :
# Gane, Rosaz, Dehu, Parigi, Dumail, Malgat, Laidin, Armani, Samat, Milan, Pournin, Paymal, Poursin, Dodane, Jayat, Parage, Samy, Malatray, Pouyade, Enjalran, Saumade, Jayol, Chenal, Sivan, Philip, Dole, Dhuy, Sarcy, Daujat, Montarnal, Mazade, Thoral, Nancy, Patry, Daridan, Thalamy, Farin, Chatry, Gahery, Buzare, Laloi, Ramat, Danna, Sarazin, Cammal, Hale, Moiroud, Vatan, Rajon, Moog,
#
# Examples of predicted Asian  names :
# Pirat, Aliphat, Pedrono, Chanat, Sutra, Brinon, Diana, Lavanant, Labe, L hote, Duguay, Tartrat, Nonnon, Tate, Pamart, Chaise, Somon, Lan, Privat, Chain, Subrin, Duc, Carn, Chassang, Salvatori, Janon, Game, Harang, Pithon, Sahuc, Cabe, Prache, Laurentin, Indart, Desanti, Chanoine, Eon, Sornin, Houdou, Priam, Rivat, Bono, Conan, Ravat, Jarno, Petipas, Ribe, Long, Dudit, Duhayon,
#
# Examples of predicted Slavic  names :
# Truc, Turin, Petin, Manin, Palut, Bac, Doucin, Py, Putin, Wicky, Canac, Smets, Renac, Solon, Meric, Truchy, Serpin, Fremin, Glevarec, Thurin, Gounin, Buzenac, Marcenac, Lina, Malbec, Stalin, Libis, Butin, Bouic, Oillic, Casanova, Michal, Furic, Marcet, Brahic, Trupin, Roc, Roullin, Govin, Kurz, Balin, Bellin, Maurin, Gibrat, Broutin, Coic, Chabrat, Pochic, Favin, Gasc,

# %% [markdown]
# <font size="3">  The Pubmed dataset has a tendancy to wrongly classify north european names as south european names

# %% [markdown]
# # Brevet des collèges

# %% [markdown]
# I've gathered data about the brevet des collèges taken by almost all middle school students in France.
#
# <font size="3">Can we infer past immigration figures from this?</font>
#
# <font size="4"><u>**NO**<u></font>
#
# First of all, because of mixed unions, a lot of descendants of immigrants have mixed origins and wear a french name (or other).
#
# Second, the models are far from the level of accuracy we would need for this, particularly in a very imbalanced population.
#
# Quick example : let's say 90% of a population is of french origin and 10% of arabic origin and the model is correct 90% of the time. Then 10% of the dominant group, that is, 9% of the population, is going to be misclassified as having an arabic name while 90% of the minority group, that is, 9% of the population as well is going to be correctly classified as having an arabic name. Half of the people predicted as having an arabic name have in fact a french name.
#
# Let's see that in practice :

# %% [markdown]
# ## FB model

# %%
df = pd.read_csv("../data/other_data/brevet_2019.csv")
df["name"] = df["noms"].str.split(" ").apply(lambda x : " ".join(x[:-1])).str.upper()
df["prenom"] = df["noms"].str.split(" ").apply(lambda x : x[-1])

df["pred_FB"] = FB_clf.predict(df["name"])
df["pred_FB"].value_counts(normalize=True)*100
# Out:
# /home/riri/miniconda3/envs/base_data/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# NorthEuropean           65.767569
# CentralSouthEuropean    13.240034
# Arabian                 11.445240
# African                  3.836014
# Slavic                   2.649154
# Indian                   1.802126
# Asian                    1.259863
# Name: pred_FB, dtype: float64

# %% [markdown]
# ## Pubmed model

# %%
df["pred_pubmed"] = pubmed_clf.predict(df["name"])
df["pred_pubmed"].value_counts(normalize=True)*100
# Out:
# NorthEuropean           62.248753
# CentralSouthEuropean    15.319190
# Arabian                  9.594019
# African                  5.663325
# Slavic                   2.892073
# Indian                   2.224206
# Asian                    2.058434
# Name: pred_pubmed, dtype: float64

# %% [markdown]
# ## Predictions correction

# %% [markdown]
# Let's assume that the names given at birth in 1890-1900 were all of european origin, which is probably not far from truth.
# How many of those names were wrongly classified as not european by the models?

# %%
## correction
fr_names.loc[~fr_names["pred"].isin(["NorthEuropean","CentralSouthEuropean"]) ,"pred"] = "NorthEuropean"
df_merge = df.merge(fr_names[fr_names["_1891_1900"] > 5][["NOM","pred"]],left_on="name",right_on="NOM",how="left")
df_merge
# Out:
#            ville code_postal                noms         name   prenom  \
# 0       manosque       04112    Alaverdyan Rafik   ALAVERDYAN    Rafik
# 1       manosque       04112       Alpin Donovan        ALPIN  Donovan
# 2       manosque       04112  Arciszewski Sunita  ARCISZEWSKI   Sunita
# 3       manosque       04112       Artaud Mathis       ARTAUD   Mathis
# 4       manosque       04112        Avena Prince        AVENA   Prince
# ...          ...         ...                 ...          ...      ...
# 313680     paris       75000    Zieseniss Milena    ZIESENISS   Milena
# 313681     paris       75000     Zimmermann Anna   ZIMMERMANN     Anna
# 313682     paris       75000     Zivkovic Sylvie     ZIVKOVIC   Sylvie
# 313683     paris       75000        Zuber Marwan        ZUBER   Marwan
# 313684     paris       75000          Zuk Oksana          ZUK   Oksana
#
#                      pred_FB           pred_pubmed         NOM  \
# 0                     Slavic  CentralSouthEuropean         NaN
# 1                     Slavic         NorthEuropean         NaN
# 2                     Slavic                Slavic         NaN
# 3              NorthEuropean         NorthEuropean      ARTAUD
# 4       CentralSouthEuropean  CentralSouthEuropean       AVENA
# ...                      ...                   ...         ...
# 313680         NorthEuropean         NorthEuropean         NaN
# 313681         NorthEuropean         NorthEuropean  ZIMMERMANN
# 313682                Slavic                Slavic         NaN
# 313683         NorthEuropean         NorthEuropean       ZUBER
# 313684                Slavic                Slavic         NaN
#
#                         pred
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3              NorthEuropean
# 4       CentralSouthEuropean
# ...                      ...
# 313680                   NaN
# 313681         NorthEuropean
# 313682                   NaN
# 313683         NorthEuropean
# 313684                   NaN
#
# [313685 rows x 9 columns]

# %%
for region in ["Arabian",'Asian',"Slavic",'African']:
    for model in ("pred_FB","pred_pubmed"):
        a = df_merge[(df_merge["pred"].isin(["NorthEuropean","CentralSouthEuropean"])) & (df_merge[model] == region)]
        b = df_merge[(df_merge[model] == region)]
        share = len(a)/len(b)
        share = round(share*100,1)
        print(region,model," : ",share,"% at least were in fact european names")
    print("")
# Out:
# Arabian pred_FB  :  16.5 % at least were in fact european names
# Arabian pred_pubmed  :  14.9 % at least were in fact european names
#
# Asian pred_FB  :  34.1 % at least were in fact european names
# Asian pred_pubmed  :  46.0 % at least were in fact european names
#
# Slavic pred_FB  :  29.1 % at least were in fact european names
# Slavic pred_pubmed  :  36.3 % at least were in fact european names
#
# African pred_FB  :  30.8 % at least were in fact european names
# African pred_pubmed  :  42.3 % at least were in fact european names

# %% [markdown]
# <font size="3"> A sizeable share of the predictions were wrong and *this is just the lower bound*.
#
# <font size="3">Let's now try a more stringent set of criteria : we include only the names for which both models agree and that weren't given in 1890-1900 :

# %%
for region in ['CentralSouthEuropean',"African","Arabian",'Indian',"Asian","Slavic"]:
    n = df_merge[(df_merge["pred_FB"] == region) & (df_merge["pred_pubmed"] == region) & (~df_merge["pred"].isin(["NorthEuropean","CentralSouthEuropean"]))].sample(50)["name"]
    print('Examples of predicted', region, " names : ")
    for i in n:
        print(i.capitalize(), end=", ")
    print('\n')
# Out:
# Examples of predicted CentralSouthEuropean  names :
# Mitanta kandolo, Lucchini-laplanche, Silveri, Kaci, Oval-martin, Pecchia, Goncalves gomes, Santos mendes, Bottalico, Perettoni, Dias vieira, Venancio, Da costa, Calcul, Brito tolosa, Pierelli, Ruffinetto, Touenti, Alves de amorim, Sousa, Delgado, Akkaya, Manzano, Vaz, Silva rocha, Doumbia - guayroso, Sebastia, Gonzalez sanchez, Garrigos-sin, Fernandes, Maggini, Villafane garberoglio, Goncalves, De carvalho, Migliaccio, Placente, Anoni, Beramice-dracan, Navarro torres, Dos reis, Demirelisci, Cayuela, De sampaio ribeiro, Yerebasmaz, Pozzobon, Bordonado, Lacerda ferreira, Fares, De barros simoes, Da silva,
#
# Examples of predicted African  names :
# Nguizani-nkiatoko, Diakite, Mombo di-lutete, Diongue, Kazi, Ndoye, Diawara, Fondjou, Connaly-missongo, Diallo, Traore, Timera, Ehue, Beseme, Kuedi, Bulawa, Sidibe, Nimaga, Toure, Ndoye, Abodunrin, Akabi, M'baye, Samah, Mpuki, Meviane, Traore, Ntumba, Cuvele, Diwulu umba, Kpodar, Kofarago, Aupy-nozile, Samba, Diallo, Merchie, Kingidi krizub mabula, Moukila m pele, Diallo, Matubanzila, Luzu, Ngonzi mbala, Fofana, Omente, Zeme, Axisa, Ndoumou, Mbizi bandoki, Peletan, Coq-papa,
#
# Examples of predicted Arabian  names :
# Grairia, Boudraa, Lakehal, Sebbar, Bouzid, Amrouche, Gouagout, Ben chaib, Oualissaou, Fani, Ketfa, Tamrabet id ouarab, Oujidi, Bachour, Chalaal, Achiba, Khelassi, Fellah, Bouchama, Bouydounan, Akarkoub, Mbarki agnaou, Khenniche, Chekroun, Hammadi, Yahmdi, Labbadli, Bousouf, Belkhir, Khlil, Aouimer, Merakeb, Belabed, Djaouani, El khalfioui, Benkahlouche, Abaidia, Benmansour, Kacemi, Abri, Choum, Bouchareb, Fadda, Boussioud, Ahjab, Kherib, Necibi, Bentata, Saada, Taieb,
#
# Examples of predicted Indian  names :
# Shabani, Misha, Sriramanan, Rahimi, Arakelian, Berian, Sheiknejad, Math, Farid, Katti, Vinandy, Rahman, Vimalenthiran, Baidah, Tolojanahary fenohaja, Ghazali, Niranjan, Sivakumar, Behrami, Bahtiyar, Ahmat moussa tijani, Hashemi, Dizay, Mannan, Joyeusaz, Mustafi, Kurdi, Kok srey, Selvay, Kotcharian, Wijayakumar, Pezanna, Saghargi, Firma, Rency, Puvikaran, Samarajeewa, Dehni, Karunanayake, Soamanatrika, Pavade, Satheeskumar, Faraj, Dolata, Abedini, Kathiravelu, Dibrani, Faria, Muhit, Sendra,
#
# Examples of predicted Asian  names :
# Wang, Danghin, Shishido, Hara, Chu, Rendy, Lecuyer-samori, Zheng, Zheng, Su, Sukami, Yang, Jao, Chu van, Shakhun, Chan, Lim, Tran, Surdol, Nguyen, Lanai, Rokita, Keo-phin, Syvanthaphanith, Chansay, Ung, Wang, Jit, Sheng, Lim, Siong, Chulem, Roda, Vu duc, Satou, Taya, Zheng, Watamalejono, Yvai, Wang, Morit, Seetaram, Nobus, Ung, Dantichan, Lerdu, Suka, Yimnai, Bardesono, Jiang,
#
# Examples of predicted Slavic  names :
# Pecyna, Zmija, Rumiel, Podda, Promerova, Wieczorek, Kusnierz, Djordjevic, Bondarec, Palka, Cieplucha, Stanatchkov, Akhaev, Kudryashova, Kolenda, Balcer, Popek, Podlyski, Melkonyan, Scieszyk, Parkin, Mandic, Nachkhoev, Temirova, Sadic, Witosz, Zajdel, Tygielski, Gabrielyan, Lukaszewski, Zawadzki, Georgieva, Skrzypczak, Martinovic, Milic, Syuleymanov, Miladinovic, Ciesielski, Hrnjic, Stevic, Pulveric, Tomasik, Kuznik, Ziverec, Dambaev, Jelic, Magamadova, Alibasic, Mehmedovic, Nesic,

# %% [markdown]
# <font size="3"> Those predictions look much better than those of the indivual models taken separately, although still far from 100% accurate.

# %% [markdown]
# # conclusion

# %% [markdown]
# <font size="3">The two datasets exhibit similar results overwhole with the Pubmed model being maybe a bit better. I would have excepted the opposite since the Facebook dataset is so much richer but maybe it's just too dirty or imbalanced. I bet there is a lot of room for improvement.
# I<font size="3">n the case of France, the Facebook dataset seems to do a bit better though.
